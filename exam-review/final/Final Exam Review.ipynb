# %% [markdown]
# # Final Exam Review

# %% [markdown]
# ## How the Exam will be Given
#
# Unless you have an accommodation from the Sara Bee Center or under quarantine you must take this Exam in the lecture room at the designated class time.
#
# Me and the Teaching Assistants will hand out exams 5 minutes prior to the beginning of class. Students may begin them at 9:25am and when they have put their non-permitted items away. You must hand in your Exam when I indicate time is up. Continuing to work on the exam after time is called will result in disqualification of your Exam.
#
# ## Exam Format
#
# The problems on the Exam will be similar in format to the Homework problems. You will not be asked to write and compile code. (You can be asked what an issue is with a code segment based on an error message)
#
# This exam is closed book: You may not use any website, books, HW solutions, Hogwarts Owls, voodoo magic, other kinds of magic, smoke signals, or your class notes.
#
# If you are caught using any unauthorized resource, you will receive an automatic 0 on the Exam and a referral to the Notre Dame Academic Honor council.

# %% [markdown]
# ## Building your Exam Study Guide
#
# The Homework questions and in-class problems have solution keys available. The objective of these problems is for you to practice the problems to set you up for success.
#
# These set of problems are longer than the actual exam. But if you can solve these problems independent of the keys or your notes, you will have set yourself up well for success on the Exam.
#
# The Exam concepts will be a subset of the material covered below. Like the midterm exam, if I do not explicitly cover it in this review, it will not be covered on the Exam. (i.e. there will not be any Python questions)

# %% [markdown]
# ## Example Questions
#
# Work to develop an example study guide for these problems. The key for all of these problems are posted.
#
# > <b>Pro tip:</b> Develop variants of problems to build your own guide!
#
# The references are based on the lecture numbers on the Spring 2025 <a href = "https://canvas.nd.edu/courses/105964/pages/lecture-notes-and-schedule">Lecture Notes and Schedule</a> page.
#
# ### True/False Multiple Choice
#
# <b>1.</b> - Reading Quiz 7 - Problems 6, 7, 8, 9
#
# <b>2.</b> - Reading Quiz 8 - Problems 1, 3
#
# <b>3.</b> - Reading Quiz 9 - Problem 4
#
# <b>4.</b> - Reading Quiz 10 - Problems 1-3: Pick static or dynamic
#
# <b>5.</b> - Reading Quiz 10 - Problem 5
#
# <b>6.</b> - Reading Quiz 11 - Problems 1, 4,5
#
# <b>7.</b> - Reading Quiz 12 - Problem 3
#
# ### Pointer Operations
#
# <b>7.</b> Homework 8 - Problem 2
#
# <b>8.</b> Homework 8 - Problem 3
#
# <b>9.</b> Homework 8 - Problem 4
#
# <b>10.</b> Homework 8 - Problem 5
#
# <b>11.</b> Homework 8 - Problem 6
#
# ### Recursive Tracing with C Pass by Reference
#
# <b>5.</b> In-Class Lecture 19 - Recursive Tracing - Pass by Reference Exam Example using ptr_trace.c
#
# <b>6.</b> Homework 9 - Problem 2
#
# <b>7.</b> Homework 9 - Problem 3
#
# ### Sorting and Searching
#
# <b>12.</b> Given an array, show the steps for an Insertion Sort. (Go to Homework 9, and go to the "Example Sort" under Part 2 - Step 1. You should show each <b>step</b>. As you may recall, there is a video where I explain each step.)
#
# Consider the integer array: {22 17 10 84 99 7 36 8 15}. Show the steps for an insertion sort.
#
# > A correct answer will look like this:
#
# <code>22 17 10 84 99 7 36 8 15</code>
#
# <code>17 22 10 84 99 7 36 8 15</code>
#
# <code>10 17 22 84 99 7 36 8 15</code>
#
# <code>7 10 17 22 84 99 36 8 15</code>
#
# <code>7 10 17 22 36 84 99 8 15</code>
#
# <code>7 8 10 17 22 36 84 99 15</code>
#
# <code>7 8 10 15 17 22 36 84 99</code>
#
# <b>13.</b> Given an array, show the steps for a Binary Search of an element. (Go to Homework 9, and go to "The Binary Search Algorithm" under Part 2 - Step 2. You should show each <b>step</b>. As you may recall, there is a video where I explain each step.)
#
# Here is an example, and an example of a correct answer.
#
# Consider the sorted integer array: <code>7 8 10 15 17 22 36 84 99</code>. Show the steps for a binary search to find the number 15.
#
# Solution:
#
# <code>min = 0, max = 8, mid = 4, array[4] = 17</code>
#
# <code>min = 0, max = 3, mid = 1, array[1] = 8</code>
#
# <code>min = 2, max = 3, mid = 2, array[2] = 10</code>
#
# <code>min = 3, max = 3, mid = 2, array[3] = 15</code>
#
# ### Memory Map Drawings
#
# <b>14.</b> In-Class Lecture 22 - Memory Map Problem
#
# <b>15.</b> In-Class Lecture 24 - Memory Map Problem for example.c
#
# <b>16.</b> Homework 11 - Problem
#
# ### C Structs and Command Line Arguments
#
# <b>17.</b> Lecture 25 - Example memory map based on structs.c and the "struct outputs"
#
# <b>18.</b> Lecture 26 - Exam Review Practice Problem based on the 26-2 Problem Statement.
#
# ### Singly Linked List
#
# <b>17.</b> Lecture 27 - Memory Map Practice Problem based on the 27-2 Problem Statement.
