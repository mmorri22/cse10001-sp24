# %% [markdown]
# ## Midterm Exam Notebook Guide
# <p></p>
# Approach to using this guide for successful Exam study:
# <ol>
#     <li>The <code>jupyterquiz</code> will not run unless you follow the directions on the Lecture Notes page by installing on Anaconda (as we also did in class)</li>
#     <li>While the questions using <code>jupyterquiz</code> are all matching or multiple choice, some questions on your actual exam will not have multiple choice / matching.</li>
#     <li>Run the <code>start_quiz_section</code> cell <i>first</i></li>
#     <tab><b>Note 1</b>: If you get the error <code><font color = 'red'>NameError</font>: name 'start_quiz_section' is not defined</code>, this means you need to run the first cell block <i>first</i><br>
#     <tab><b>Note 2</b>: The solutions are based on scripts I have written that are stored online, so this review requires <b>consistent internet access</b><p>
#     <li>Attempt the problems first <i>before</i> reviewing the solutions!</li>
#     <tab>Remember the "Hands-on imperative". Build those brain links in long-term memory!</tab><p>
#     <li>Form study groups!</li><p>
#     <li>Ask questions of your classmates in the Slack!</li><p>
#     <li>One of the best ways to learn how code should work properly is to review and fix improper code</li><p>
#     <li>To practice again, go to <b>Kernel -> Restart and Clear Output</b> to refresh so you can practice again</li><p>
#     <tab><b>Note</b>: If you do this, don't forget to run the <code>start_quiz_section</code> cell</tab><p>
#     <li>Challenge yourself and your study partners by <b>designing your own problems</b></li><p>
# </ol>

# %%
# You *must* run this command in order for the quiz applets to properly operate
# Otherwise, you will get NameError: name 'start_quiz_section' is not defined

def start_quiz_section( path ):

    from jupyterquiz import display_quiz
    git_path="https://raw.githubusercontent.com/mmorri22/cse10001-sp24/main/exam-review/midterm/"
    full_path = git_path + path
    display_quiz(full_path)

# %% [markdown]
# ### 1. Definitions
# <p></p>
# Here, you will be asked to <b>match</b> terms with their definitions. Use the tables below for matching with the specified problem (For example, for Problem 7b, you will be asked to identify which definition on the right is the definition of SDK)

# %% [markdown]
# #### For the Matching Problem 3 - Use this table to reference the matches after you run <code>start_quiz_section( "midterm_definitions.json" )</code> below:
#
# | Term                   | Definitions                     |
# |:-----------------------|:---------------------------------|
# | Device Driver         | 1 - Manages the hardware of a computer and makes it possible to run other programs.    |
# | Application  | 2 - Acts as a bridge to a specific hardware device. |
# | Operating System         | 3 - Self-contained program focused on a single task. |

# %% [markdown]
# #### For the Matching Problem 4 - Use the following mappings after you run <code>start_quiz_section( "midterm_definitions.json" )</code> below:
#
# | Term                   | Definitions                     |
# |:-----------------------|:---------------------------------|
# | Turing Machine         | 1 - A large computer with a number of processors and lots of memory.    |
# | Distributed Computing  | 2 - An idealized machine that serves as a universal model of computation. |
# | Super Computer         | 3 - A specialized processor that perform graphics computations much faster than conventional CPUs. |
# | GPU                    | 4 - A system where a group of independent computers communicate to solve problems. |

# %% [markdown]
# #### For the Matching Problem 7 - Use the following terms and definitions (number) to match after you run <code>start_quiz_section( "midterm_definitions.json" )</code> below:
#
# | Term                   | Definitions                     |
# |:-----------------------|:---------------------------------|
# | Library         | 1 - Description of what services a system provides.    |
# | SDK  | 2 - Collection of related functions. |
# | Bug         | 3 - Translates high-level code to machine code. |
# | API                    | 4 - An environment and supporting tools for a particular platform. |
# | Assembler         | 5 - Flaw in a piece of software. |
# | Compiler                    | 6 - Translates low-level code to machine code. |

# %%
# Run this line to generate a set of problems for definitions - multiple choide
# Remember that you need to run start_quiz_section once otherwise this will not work

start_quiz_section("midterm_definitions.json")
# Out:
# <div id="KrUFPPXdAtEB" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #KrUFPPXdAtEB {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Answer {
#     margin: 10px 0;
#     display: grid;
#     grid-template-columns: 1fr 1fr;
#     grid-gap: 10px;
#     border-radius: inherit;
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
#     min-height: 2em;
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: 140px;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     outline: none;
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     padding: 10px;
#     background: var(--jq-numeric-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .InpLabel {
#     line-height: 34px;
#     float: left;
#     margin-right: 10px;
#     color: var(--jq-numeric-input-label);
#     font-size: 15pt;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     color: var(--jq-text-color);
#     box-shadow: inset 0px 0px 5px var(--jq-mc-button-inset-shadow);
#     outline: none;
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     color: var(--jq-text-color);
#     box-shadow: inset 0px 0px 5px var(--jq-mc-button-inset-shadow);
#     outline: none;
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
# </style>

# %% [markdown]
# ### 2. Hardware
# You will need to know the following:
# <ol>
#     <li>What is a computer?</li>
#     <li>How is a computer logically constructed?</li>
#     <li>What is the role of the CPU, RAM, Disk, and I/O devices?</li>
#     <li>What sort of operations does a CPU support?</li>
#     <li>What is the execution model of a CPU?</li>
# </ol>

# %%
#### Run this line to generate a set of problems for hardware
# Remember that you need to run start_quiz_section once otherwise this will not work

start_quiz_section( "midterm_hardware.json" )
# Out:
# <div id="JXPKVyHYkpSE" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #JXPKVyHYkpSE {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Answer {
#     margin: 10px 0;
#     display: grid;
#     grid-template-columns: 1fr 1fr;
#     grid-gap: 10px;
#     border-radius: inherit;
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
#     min-height: 2em;
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: 140px;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     outline: none;
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     padding: 10px;
#     background: var(--jq-numeric-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .InpLabel {
#     line-height: 34px;
#     float: left;
#     margin-right: 10px;
#     color: var(--jq-numeric-input-label);
#     font-size: 15pt;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     color: var(--jq-text-color);
#     box-shadow: inset 0px 0px 5px var(--jq-mc-button-inset-shadow);
#     outline: none;
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     color: var(--jq-text-color);
#     box-shadow: inset 0px 0px 5px var(--jq-mc-button-inset-shadow);
#     outline: none;
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
# </style>

# %% [markdown]
# ### 3. Information Representation
# <p></p>
# In this section, you will demonstrate your understanding of how information is represented in a computer. Example topics include:<p>
# <ol>
#     <li>What is the difference between <b>analog</b> and <b>digital</b> information?</li>
#     <li>How do you convert a number from decimal to <b>binary</b>? <b>hexadecimal</b>? <b>vice versa</b>?</li>
#     <li>What is the difference between <code>KB</code>, <code>MB</code>, <code>GB</code>, <code>TB</code>?</li>
#     <li>How are <font color='red'><b>colors</b></font> represented on a computer?</li>
# </ol>

# %%
# Run this line to generate a set of problems for information representation
# Remember that you need to run start_quiz_section once otherwise this will not work

start_quiz_section( "midterm_information_representation.json" )
# Out:
# <div id="EojCNGJfBOit" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #EojCNGJfBOit {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Answer {
#     margin: 10px 0;
#     display: grid;
#     grid-template-columns: 1fr 1fr;
#     grid-gap: 10px;
#     border-radius: inherit;
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
#     min-height: 2em;
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: 140px;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     outline: none;
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     padding: 10px;
#     background: var(--jq-numeric-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .InpLabel {
#     line-height: 34px;
#     float: left;
#     margin-right: 10px;
#     color: var(--jq-numeric-input-label);
#     font-size: 15pt;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     color: var(--jq-text-color);
#     box-shadow: inset 0px 0px 5px var(--jq-mc-button-inset-shadow);
#     outline: none;
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     color: var(--jq-text-color);
#     box-shadow: inset 0px 0px 5px var(--jq-mc-button-inset-shadow);
#     outline: none;
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
# </style>

# %% [markdown]
# ### 4. Conditional Execution Problems
# You will need to know the following:
# <li>What are <b>boolean expressions</b>?</li>
# <li>How do we perform <b>conditional execution</b>? <b>alternative execution</b>? <b>chained conditionals</b>?</li>

# %%
# Run this line to generate a set of problems for conditional execution
# Remember that you need to run start_quiz_section once otherwise this will not work

start_quiz_section( "midterm_conditional_execution.json" )
# Out:
# <div id="bijeoMCukNto" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #bijeoMCukNto {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Answer {
#     margin: 10px 0;
#     display: grid;
#     grid-template-columns: 1fr 1fr;
#     grid-gap: 10px;
#     border-radius: inherit;
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
#     min-height: 2em;
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: 140px;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     outline: none;
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     padding: 10px;
#     background: var(--jq-numeric-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .InpLabel {
#     line-height: 34px;
#     float: left;
#     margin-right: 10px;
#     color: var(--jq-numeric-input-label);
#     font-size: 15pt;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     color: var(--jq-text-color);
#     box-shadow: inset 0px 0px 5px var(--jq-mc-button-inset-shadow);
#     outline: none;
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     color: var(--jq-text-color);
#     box-shadow: inset 0px 0px 5px var(--jq-mc-button-inset-shadow);
#     outline: none;
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
# </style>

# %% [markdown]
# #### Conditional Execution Problem 1 - See for Yourself!
# <p></p>
# Given the function <b>prob_1</b>, state the outputs for the following runs:
# <ol>
#     <li><code>prob_1(5)</code></li>
#     <li><code>prob_1(10)</code></li>
#     <li><code>prob_1(3)</code></li>
# </ol>

# %%
# Here you can determine the code for the first problem for yourself!
def prob_1(x):
    if x < 5:
        print('Yes')
    elif x % 2 == 1:
        print('Maybe')
    else:
        print('No')

# %%
print( "Problem 1 - with an input of 5:")
prob_1(5)
# Out:
# Problem 1 - with an input of 5:
# Maybe

# %%
print( "Problem 1 - with an input of 10:")
prob_1(10)
# Out:
# Problem 1 - with an input of 10:
# No

# %%
print( "Problem 1 - with an input of 3:")
prob_1(3)
# Out:
# Problem 1 - with an input of 3:
# Yes

# %% [markdown]
# #### Conditional Execution - Problem 2
# What is the final value of x?

# %%
def increment(x):
    x = x + 2
    return x
    
def decrement(x):
    return x - 2

x = 1
increment(x)
x = increment(x)
decrement(x)
x = decrement(x)
x = increment(decrement(x))
x = decrement(increment(x))

print(x)
# Out:
# 1

# %% [markdown]
# ### 5. Repeated Execution
# <p></p>
# You will need to know the following:
# <ol>
#     <li>How do we perform <b>repeated execution</b> based on a <font color='red'><b>condition</b></font>?</li>
#     <li>How do we perform <b>repeated execution</b> over a <font color='green'><b>sequence</b></font>?</li>
# </ol>

# %%
# Run this line to generate a set of problems for repeared execution
# Remember that you need to run start_quiz_section once otherwise this will not work

start_quiz_section( "midterm_repeated_execution.json" )
# Out:
# <div id="BhxwVFgIaQcZ" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #BhxwVFgIaQcZ {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Answer {
#     margin: 10px 0;
#     display: grid;
#     grid-template-columns: 1fr 1fr;
#     grid-gap: 10px;
#     border-radius: inherit;
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
#     min-height: 2em;
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: 140px;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     outline: none;
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     padding: 10px;
#     background: var(--jq-numeric-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .InpLabel {
#     line-height: 34px;
#     float: left;
#     margin-right: 10px;
#     color: var(--jq-numeric-input-label);
#     font-size: 15pt;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     color: var(--jq-text-color);
#     box-shadow: inset 0px 0px 5px var(--jq-mc-button-inset-shadow);
#     outline: none;
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     color: var(--jq-text-color);
#     box-shadow: inset 0px 0px 5px var(--jq-mc-button-inset-shadow);
#     outline: none;
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
# </style>

# %% [markdown]
# #### Repeated Execution Problem 1 - See for Yourself!
# <p></p>
# Given the code, determine the output:

# %%
index = 1
count = 0
while index <= 20:
    if index % 3 == 0:
        count += 1
    index += 1

print(count)
# Out:
# 6

# %% [markdown]
# ### Conditional Execution - Problem 3 - Try on your Own!
# The Python code below is suppose to count all of the even numbers between 1 and 100 (inclusive) that are <b><i>also</i></b> a multiple of 5, but it contains some errors. Identify and fix the errors:

# %%
iterator = 0
total = 0
while iterator < 100:
    if iterator % 2 == 0 or iterator % 5 == 0:
        total += 1
    iterator += 1

print(total)
print("Hint: The answer should be 550")
# Out:
# 60
# Hint: The answer should be 550

# %%
# Run this line to show the solution for repeated execution Problem 3
# Remember that you need to run start_quiz_section once otherwise this will not work

start_quiz_section("midterm-repeated-prob3-solution.json")
# Out:
# <div id="NxvfJltCerOa" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #NxvfJltCerOa {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Answer {
#     margin: 10px 0;
#     display: grid;
#     grid-template-columns: 1fr 1fr;
#     grid-gap: 10px;
#     border-radius: inherit;
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
#     min-height: 2em;
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: 140px;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     outline: none;
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     padding: 10px;
#     background: var(--jq-numeric-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .InpLabel {
#     line-height: 34px;
#     float: left;
#     margin-right: 10px;
#     color: var(--jq-numeric-input-label);
#     font-size: 15pt;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     color: var(--jq-text-color);
#     box-shadow: inset 0px 0px 5px var(--jq-mc-button-inset-shadow);
#     outline: none;
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     color: var(--jq-text-color);
#     box-shadow: inset 0px 0px 5px var(--jq-mc-button-inset-shadow);
#     outline: none;
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
# </style>

# %% [markdown]
# ### 6. Algorithms
# <p></p>
# You will need to know the following:
# <ol>
#     <li>What is an <b>algorithm</b>?</li>
#     <li>How do we measure and evaluate <b>time complexity</b>?</li>
#     <li>What is the time complexity of <b>linear search</b>? <b>binary search</b>? <b>sorting</b>?</li>
# </ol>

# %%
# Run this line to generate a set of problems for algorithms
# Remember that you need to run start_quiz_section once otherwise this will not work

start_quiz_section( "midterm_algorithms.json" )
# Out:
# <div id="PRuCEhxRBJzg" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #PRuCEhxRBJzg {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Answer {
#     margin: 10px 0;
#     display: grid;
#     grid-template-columns: 1fr 1fr;
#     grid-gap: 10px;
#     border-radius: inherit;
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
#     min-height: 2em;
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: 140px;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     outline: none;
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     padding: 10px;
#     background: var(--jq-numeric-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .InpLabel {
#     line-height: 34px;
#     float: left;
#     margin-right: 10px;
#     color: var(--jq-numeric-input-label);
#     font-size: 15pt;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     color: var(--jq-text-color);
#     box-shadow: inset 0px 0px 5px var(--jq-mc-button-inset-shadow);
#     outline: none;
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     color: var(--jq-text-color);
#     box-shadow: inset 0px 0px 5px var(--jq-mc-button-inset-shadow);
#     outline: none;
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
# </style>

# %%
# Problem 1 - Try for yourself
def contains( numbers_list, target_value ):
    for number in numbers_list:
        if number == target_value:
            return True
    
    return False

# %%
# Problem 2 - Try for yourself
# Input - sorted list, target value
def search( numbers_list, target_value ):
    
    min_val = 0
    max_val = len(numbers_list) - 1
    
    while min_val <= max_val:
        
        mid_val = ( max_val + min_val ) // 2
    
        if numbers_list[ mid_val ] == target_value:
            return True
        
        if numbers_list[ mid_val ] > target_value:
            max_val = mid_val - 1
            
        elif numbers_list[ mid_val ] < target_value:
            min_val = mid_val + 1
            
    return False

# Test
numbers_list = [1, 3, 4, 5, 7, 13, 16, 18, 22, 24, 25, 27]

print( search( numbers_list, 5 ) )
print( search( numbers_list, 8 ) )
print( search( numbers_list, 18 ) )
print( search( numbers_list, 17 ) )
print( search( numbers_list, 29 ) )
print( search( numbers_list, 1 ) )
print( search( numbers_list, -1 ) )
# Out:
# True
# False
# True
# False
# False
# True
# False

# %%
# Problem 3
def sort( numbers_list ):
    
    iterator_1 = 0
    while iterator_1 < len(numbers_list) - 1:
        
        iterator_2 = iterator_1 + 1
        index = iterator_1 + 1
        
        while iterator_2 < len(numbers_list):
            
            if numbers_list[index] > numbers_list[ iterator_2 ]:
                index = iterator_2
                
            iterator_2 += 1
            
        temp = numbers_list[index]
        numbers_list[index] = numbers_list[iterator_1]
        numbers_list[iterator_1] = temp
        
        iterator_1 += 1
        
    return numbers_list

sort( [10, 13, 1, 22, 7, 6, 5, 14, 8] )
# Out:
# [1, 5, 6, 7, 8, 13, 14, 22, 10]

# %%
# Problem 3 - Try for yourself

def prob_3( int_val ):
    
    if int_val <= 1:
        return 2
    
    if int_val % 2 == 1:
        return int_val + prob_3( int_val - 2 )
    
    else:
        return int_val + prob_3( int_val - 1 )
    
prob_3( 8 )
# Out:
# 25

# %%
# Problem 4 - Try for yourself
# Broken up to show example of a Recursive Trace

def prob_4( x ):
    
    if x <= 3:
        print( "Reached base case and returns 2")
        return 2
    
    print( f'At prob_4({x}), Making left call with prob_4({x-2})')
    
    left_val = prob_4( x - 2 )
    
    print( f'At prob_4({x}), Making right call with prob_4({x-3})')
    
    right_val = prob_4( x - 3 )
    
    print( f'At prob_4({x}), Returning the sum of {left_val} and {right_val} = {left_val + right_val}')
    
    return left_val + right_val

print( prob_4(6) )
# Out:
# At prob_4(6), Making left call with prob_4(4)
# At prob_4(4), Making left call with prob_4(2)
# Reached base case and returns 2
# At prob_4(4), Making right call with prob_4(1)
# Reached base case and returns 2
# At prob_4(4), Returning the sum of 2 and 2 = 4
# At prob_4(6), Making right call with prob_4(3)
# Reached base case and returns 2
# At prob_4(6), Returning the sum of 4 and 2 = 6
# 6

# %% [markdown]
# ### 7. Data Structures: List
# You will need to know the following:
# <ol>
#     <li>What is a <b>list</b>?</li>
#     <li>How do we <b>construct</b> a list?</li>
#     <li>How do we <b>access an element in</b> a list?</li>
#     <li>How do we <b>iterate through</b> a list?</li>
#     <li>How do we <b>search</b> a list?</li>
#     <li>How do we <b>slice</b> a list?</li>
#     <li>How do we <b>add to</b> a list?</li>
#     <li>How do we <b>sort</b> a list?</li>
# </ol>

# %% [markdown]
# #### For the Matching Problem - Problem 1 - Use the following mappings after you run <code>start_quiz_section( "midterm_list.json" )</code>:
#
# Match the array access code segment with a specific output for the following code:<p></p>
# <code>colors = ['red', 'green', 'blue', 'yellow']</code>
#
# | Code                   | Vaue                     |
# |:-----------------------|:---------------------------------|
# | <code>colors[0]</code>         | 1 - yellow.    |
# | <code>colors[2]</code>  | 2 - red |
# | <code>colors[-1]</code>         | 3 - Error message: IndexError: list index out of range |
# | <code>colors[-3]</code>                    | 4 - green |
# | <code>colors[4]</code>                    | 5 - blue |

# %%
# Run this line to generate a set of problems for lists
# Remember that you need to run start_quiz_section once otherwise this will not work

start_quiz_section( "midterm_list.json" )
# Out:
# <div id="aQtpuuCALAwv" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #aQtpuuCALAwv {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Answer {
#     margin: 10px 0;
#     display: grid;
#     grid-template-columns: 1fr 1fr;
#     grid-gap: 10px;
#     border-radius: inherit;
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
#     min-height: 2em;
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: 140px;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     outline: none;
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     padding: 10px;
#     background: var(--jq-numeric-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .InpLabel {
#     line-height: 34px;
#     float: left;
#     margin-right: 10px;
#     color: var(--jq-numeric-input-label);
#     font-size: 15pt;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     color: var(--jq-text-color);
#     box-shadow: inset 0px 0px 5px var(--jq-mc-button-inset-shadow);
#     outline: none;
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     color: var(--jq-text-color);
#     box-shadow: inset 0px 0px 5px var(--jq-mc-button-inset-shadow);
#     outline: none;
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
# </style>

# %%
# Problem 1 - Try Yourself
colors = ['red', 'green', 'blue', 'yellow']

print( f'colors[0] = {colors[0]}' )
print( f'colors[2] = {colors[2]}' )
print( f'colors[-1] = {colors[-1]}' )
print( f'colors[-3] = {colors[-3]}' )
print( f'colors[4] = {colors[4]}' )
# Out:
# colors[0] = red
# colors[2] = blue
# colors[-1] = yellow
# colors[-3] = green
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24960\1565731078.py in <module>
#       6 print( f'colors[-1] = {colors[-1]}' )
#       7 print( f'colors[-3] = {colors[-3]}' )
# ----> 8 print( f'colors[4] = {colors[4]}' )
#
# IndexError: list index out of range

# %%
# Problem 2 - Try Yourself
colors = ['red', 'green', 'blue', 'yellow']

print( f'colors[:2] = {colors[:2]}' )
print( f'colors[2:] = {colors[2:]}' )
print( f'colors[1:2] = {colors[1:2]}' )
print( f'colors[:] = {colors[:]}' )

# %%
# Problem 3 - Try Yourself
colors = ['red', 'green', 'blue', 'yellow']

print( sorted(colors[2:]) )

# %%
# Problem 3 - Try Yourself
colors = ['red', 'green', 'blue', 'yellow']

print( sorted(colors[:2]) )

# %% [markdown]
# ### 8. Data Structures: Dictionary
# <p></p>
# You will need to know the following:
# <ol>
# 	<li>What is a <b>dict</b>?</li>
# 	<li>How do we <b>construct</b> a dict?</li>
# 	<li>How do we <b>access an element</b> in a dict?</li>
# 	<li>How do we <b>iterate through</b> a dict?</li>
# 	<li>How do we <b>search</b> a dict?</li>
# </ol>

# %%
# Run this line to generate a set of problems for dicts
start_quiz_section( "midterm_dictionary.json" )

# %%
# Problem 2 - Try it yourself
TABLE = {
    'harry' : 'potter',
    'ron' : 'weasley',
    'hermonie' : 'granger',
    'draco' : 'malfoy'
}

TABLE.keys()

# %%
# Problem 3 - Try it yourself
TABLE = {
    'harry' : 'potter',
    'ron' : 'weasley',
    'hermonie' : 'granger',
    'draco' : 'malfoy'
}

TABLE.values()

# %%
# Problem 4 - Try it yourself
TABLE = {
    'harry' : 'potter',
    'ron' : 'weasley',
    'hermonie' : 'granger',
    'draco' : 'malfoy'
}

TABLE.items()

# %%
name = 'Harry Potter and the Goblet of Fire'

counts = {}

for letter in name:
    counts[letter] = counts.get(letter,0) + 1
    
a_char = 'a'
o_char = 'o'
t_char = 't'
    
print( f'counts[\'a\'] = { counts[a_char] }' )
print( f'counts[\'o\'] = { counts[o_char] }' )
print( f'counts[\'t\'] = { counts[t_char] }' )
print( f'max(counts.values()) = { max(counts.values()) }' )
